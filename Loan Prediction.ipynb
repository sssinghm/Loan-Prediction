# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loan_data.csv')

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
df.describe().T
# Out:
#                     count          mean           std         min  \
# credit.policy      9578.0      0.804970      0.396245    0.000000
# int.rate           9578.0      0.122640      0.026847    0.060000
# installment        9578.0    319.089413    207.071301   15.670000
# log.annual.inc     9578.0     10.932117      0.614813    7.547502
# dti                9578.0     12.606679      6.883970    0.000000
# fico               9578.0    710.846314     37.970537  612.000000
# days.with.cr.line  9578.0   4560.767197   2496.930377  178.958333
# revol.bal          9578.0  16913.963876  33756.189557    0.000000
# revol.util         9578.0     46.799236     29.014417    0.000000
# inq.last.6mths     9578.0      1.577469      2.200245    0.000000
# delinq.2yrs        9578.0      0.163708      0.546215    0.000000
# pub.rec            9578.0      0.062122      0.262126    0.000000
# not.fully.paid     9578.0      0.160054      0.366676    0.000000
#
# ...

# %%
df.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
df['credit.policy'].value_counts()
# Out:
# credit.policy
# 1    7710
# 0    1868
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6), dpi=300)

df[df['credit.policy'] == 0]['fico'].hist(bins=35, alpha=0.5, color='red', label='Credit 0')

df[df['credit.policy'] == 1]['fico'].hist(bins=35, alpha=0.5, color='blue', label ='Credit 1')

plt.legend()
plt.xlabel('FICO Score')
plt.ylabel('Count')
plt.title('FICO Score Distribution by Credit policy')
plt.show()

# %%
df['not.fully.paid'].value_counts()
# Out:
# not.fully.paid
# 0    8045
# 1    1533
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))

df[df['not.fully.paid'] == 0]['fico'].hist(
    bins=35, alpha=0.5, color='red', label='Fully Paid'
)

df[df['not.fully.paid'] == 1]['fico'].hist(
    bins=35, alpha=0.5, color='blue', label='Not Fully Paid'
)

plt.legend()
plt.xlabel('FICO Score')
plt.title('FICO Score Distribution by Loan Status')
plt.show()

# %%
plt.figure(figsize=(15, 7), dpi=300)
count=sns.countplot(data=df, x='purpose', hue='not.fully.paid', palette='YlGn')
count.legend(title='Loan Status', labels=['Fully Paid', 'Not Fully Paid'])
plt.xlabel('Purpose')
plt.ylabel('Count')
plt.show()

# %%
sns.jointplot(data=df, x='fico', y='int.rate', color='cyan')
plt.xlabel('FICO Score')
plt.ylabel('Interest Rate')
plt.show()

# %%
g = sns.lmplot(data=df, x='fico', y='int.rate', hue='credit.policy', col='not.fully.paid', palette='Set1')

new_titles = {0: 'Fully Paid', 1: 'Not Fully Paid'}

for ax, title in zip(g.axes.flat, df['not.fully.paid'].unique()):
    ax.set_title(new_titles[title])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
final_data = pd.get_dummies(data=df, columns=['purpose'], drop_first=True, dtype=int)
final_data
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   credit.policy               9578 non-null   int64
#  1   int.rate                    9578 non-null   float64
#  2   installment                 9578 non-null   float64
#  3   log.annual.inc              9578 non-null   float64
#  4   dti                         9578 non-null   float64
#  5   fico                        9578 non-null   int64
#  6   days.with.cr.line           9578 non-null   float64
#  7   revol.bal                   9578 non-null   int64
#  8   revol.util                  9578 non-null   float64
#  9   inq.last.6mths              9578 non-null   int64
#  10  delinq.2yrs                 9578 non-null   int64
#  11  pub.rec                     9578 non-null   int64
#  12  not.fully.paid              9578 non-null   int64
# ...

# %%
from sklearn.model_selection import train_test_split
X = final_data.drop('not.fully.paid', axis=1)
y = final_data['not.fully.paid']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ### DECISION TREE MODEL

# %%
from sklearn.tree import DecisionTreeClassifier
d_tree = DecisionTreeClassifier()
d_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions1 = d_tree.predict(X_test)

# %%
from sklearn.metrics import classification_report 
print(classification_report(y_test, predictions1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84      2431
#            1       0.19      0.24      0.21       443
#
#     accuracy                           0.73      2874
#    macro avg       0.52      0.53      0.53      2874
# weighted avg       0.75      0.73      0.74      2874

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(d_tree, X_test, y_test)
plt.figure(figsize=(4,5), dpi=300)
plt.show()

# %% [markdown]
# ### RANDOM FOREST MODEL

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=300)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
predictions2 = rf.predict(X_test)
print(classification_report(y_test, predictions2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2431
#            1       0.58      0.02      0.05       443
#
#     accuracy                           0.85      2874
#    macro avg       0.71      0.51      0.48      2874
# weighted avg       0.81      0.85      0.78      2874

# %%
ConfusionMatrixDisplay.from_predictions(predictions2, y_test)
plt.figure(figsize=(4,5), dpi=300)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf = RandomForestClassifier()

# %%
parameters = {
    'n_estimators': np.arange(50, 401, 50),
    'criterion': ["gini", "entropy"],
    'max_features': ["sqrt", "log2"],  # removed 'auto'
    'n_jobs': [-1]  # This should be passed to the model, not in param_grid
}

# %%
grid = GridSearchCV(rf, parameters, cv=5, verbose=1)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': array([ 50, 100, 150, 200, 250, 300, 350, 400]),
#                          'n_jobs': [-1]},
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_features': 'sqrt',
#  'n_estimators': np.int64(150),
#  'n_jobs': -1}

# %%
grid_predictions = grid.predict(X_test)

# %%
print(classification_report(y_test, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2431
#            1       0.62      0.02      0.04       443
#
#     accuracy                           0.85      2874
#    macro avg       0.73      0.51      0.48      2874
# weighted avg       0.81      0.85      0.78      2874

# %%
ConfusionMatrixDisplay.from_predictions(y_test, grid_predictions)
plt.figure(figsize=(4,5), dpi=300)
plt.show()

# %% [markdown]
# #### Successfully evaluated Random Forest Classifier as the best model for the given dataset
